# %% [markdown]
# # Let us create several databases in postgreSQL that will be used to create FLASK APIs for the endpoint to call upon for visualization and for model predictions

# %%
# Dependencies
import pandas as pd
import numpy as np
import os

# globally set max columns and max rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

home = os.path.abspath("")
clean_data = os.path.join(home, "clean_data")
print(home)
print(clean_data)

# %%
# read in .csv as pandas dataframe
path = os.path.join(clean_data, "total_ML_data.csv")

df = pd.read_csv(path)
df.head()

# %%
# number of rows and # of columns
df.shape

# %%
# All columns in .csv file, all 43 of them
df.columns

# %%
df.dtypes

# %%
df_mean = df[['conductivity', 'hardness', 'turbidity', 'chlorophyll',
       'ammonia', 'nitrate_ite', 'aluminum', 'barium', 'calcium', 'carbon',
       'chloride', 'chromium', 'copper', 'magnesium', 'manganese', 'mercury',
       'molybdenum', 'phosphorus', 'potassium', 'silicon', 'sodium',
       'strontium', 'sulphate', 'vanadium', 'zinc']].mean().copy()
df_mean
pd_series = pd.Series(["Total"], index=["lake"])
total = pd_series.append(df_mean)
total

# %%
df_groupby = df.groupby("lake").mean().copy()

# %%
df_groupby.reset_index(inplace=True)
df_groupby

# %%
df_total = df_groupby.append(total, ignore_index=True)
df_total

# %%
df_total.dtypes

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

y = df["lake"].unique().copy()

label_encoder.fit(y)
encode_y = label_encoder.transform(y)

encode_y

# %%
dic_df = {
    "lake": y,
    "lake_encode": encode_y
}
df2 = pd.DataFrame(dic_df)
df2

# %%
df2.dtypes

# %% [markdown]
# # Connect to AWS Database

# %%
from sqlalchemy import create_engine
from config.postgres import username, password


rds_connection_string = f"postgresql://{username}:{password}@awsgreatlakes.cdb9inonioij.us-east-2.rds.amazonaws.com:5432/awsgreatlakes"

engine = create_engine(rds_connection_string)

# %%
# get table names
engine.table_names()

# %%
# table headers are set up correctly
pd.read_sql_query('select * from encoded_lakes', con=engine)

# %%
# read the pandas dataframe to the postgreSQL database
df2.to_sql(name='encoded_lakes', con=engine, if_exists='append', index=False)

# %%
# table headers are set up correctly
pd.read_sql_query('select * from lake_means', con=engine)

# %%
# read the pandas dataframe to the postgreSQL database
df_total.to_sql(name='lake_means', con=engine, if_exists='append', index=False)

# %%
# load up "total.csv" and export it to the postgresql database
# read in .csv as pandas dataframe
path_all = os.path.join(clean_data, "total.csv")

df_all = pd.read_csv(path_all)
df_all.head()

# %%
df_all['date_collect'] =  pd.to_datetime(df_all['date_collect'], infer_datetime_format=True)
df_all.dtypes

# %%
# get table names
engine.table_names()

# %%
# table headers are set up correctly
pd.read_sql_query('select * from master_data', con=engine)

# %%
# read the pandas dataframe to the postgreSQL database
df_all.to_sql(name='master_data', con=engine, if_exists='append', index=False)

# %%
# load up "total.csv" and export it to the postgresql database
# read in .csv as pandas dataframe
path_meta = os.path.join(clean_data, "total_metadata.csv")

df_meta = pd.read_csv(path_meta)
df_meta.head()

# %%
df_meta['date_collect'] =  pd.to_datetime(df_meta['date_collect'], infer_datetime_format=True)
df_meta.dtypes

# %%
# get table names
engine.table_names()

# %%
# table headers are set up correctly
pd.read_sql_query('select * from metadata', con=engine)

# %%
# read the pandas dataframe to the postgreSQL database
df_meta.to_sql(name='metadata', con=engine, if_exists='append', index=False)

# %%
# load up "total.csv" and export it to the postgresql database
# read in .csv as pandas dataframe
path_data = os.path.join(clean_data, "total_ML_data.csv")

df_data = pd.read_csv(path_data)
df_data.head()

# %%
df_data.dtypes

# %%
# get table names
engine.table_names()

# %%
# table headers are set up correctly
pd.read_sql_query('select * from data', con=engine)

# %%
# read the pandas dataframe to the postgreSQL database
df_data.to_sql(name='data', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Put training and testing data into AWS postgreSQL database

# %%
# Dependencies
import pandas as pd
import numpy as np
import os

# globally set max columns and max rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

home = os.path.abspath("")
clean_data = os.path.join(home, "clean_data")
print(home)
print(clean_data)
# Out:
# C:\Users\danie\OneDrive\Documents\Great_Lakes_ML
# C:\Users\danie\OneDrive\Documents\Great_Lakes_ML\clean_data

# %%
# read in .csv as pandas dataframe
path = os.path.join(clean_data, "total_ML_data.csv")

df = pd.read_csv(path)
df.head()
# Out:
#    lake  conductivity  hardness  turbidity  chlorophyll  ammonia  nitrate_ite  \
# 0  erie         249.0       NaN        NaN       9200.0  54000.0    1270000.0
# 1  erie         337.0       NaN        NaN      14400.0  14000.0    3440000.0
# 2  erie         325.0       NaN        NaN       3300.0  20000.0    3580000.0
# 3  erie         238.0       NaN        NaN       2600.0  16000.0     920000.0
# 4  erie         234.0       NaN        NaN       2500.0  12000.0     610000.0
#
#    aluminum  barium  calcium  carbon    chloride  chromium  copper  magnesium  \
# 0       NaN     NaN      NaN     NaN  12500000.0       NaN     NaN        NaN
# 1       NaN     NaN      NaN     NaN  24000000.0       NaN     NaN        NaN
# 2       NaN     NaN      NaN     NaN  16300000.0       NaN     NaN        NaN
# 3       NaN     NaN      NaN     NaN  11200000.0       NaN     NaN        NaN
# 4       NaN     NaN      NaN     NaN   9900000.0       NaN     NaN        NaN
#
#    manganese  mercury  molybdenum  phosphorus  potassium    silicon  sodium  \
# 0        NaN      NaN         NaN    117000.0        NaN   900000.0     NaN
# 1        NaN      NaN         NaN    342000.0        NaN  1570000.0     NaN
# 2        NaN      NaN         NaN     90000.0        NaN  1390000.0     NaN
# 3        NaN      NaN         NaN     15000.0        NaN   730000.0     NaN
# 4        NaN      NaN         NaN     22000.0        NaN   380000.0     NaN
#
#    strontium  sulphate  vanadium  zinc
# 0        NaN       NaN       NaN   NaN
# 1        NaN       NaN       NaN   NaN
# 2        NaN       NaN       NaN   NaN
# 3        NaN       NaN       NaN   NaN
# 4        NaN       NaN       NaN   NaN

# %%
df.columns
# Out:
# Index(['lake', 'conductivity', 'hardness', 'turbidity', 'chlorophyll',
#        'ammonia', 'nitrate_ite', 'aluminum', 'barium', 'calcium', 'carbon',
#        'chloride', 'chromium', 'copper', 'magnesium', 'manganese', 'mercury',
#        'molybdenum', 'phosphorus', 'potassium', 'silicon', 'sodium',
#        'strontium', 'sulphate', 'vanadium', 'zinc'],
#       dtype='object')

# %%
# create an X (data) and y (labels)
y = df["lake"].copy()
y_array = y.values

# use label encoder to replace string with numerical values
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

label_encoder.fit(y_array)

encode_y = label_encoder.transform(y_array)

encode_y

X = df.copy()
X.drop(["lake"], axis=1, inplace=True)
X_array = X.values

encode_y
# Out:
# array([0, 0, 0, ..., 3, 3, 3])

# %%
X_array
# Out:
# array([[2.49e+02,      nan,      nan, ...,      nan,      nan,      nan],
#        [3.37e+02,      nan,      nan, ...,      nan,      nan,      nan],
#        [3.25e+02,      nan,      nan, ...,      nan,      nan,      nan],
#        ...,
#        [1.04e+02, 4.80e+07, 5.50e-01, ..., 3.60e+06, 3.00e+02, 4.00e+02],
#        [1.05e+02, 4.80e+07, 5.30e-01, ..., 3.70e+06, 3.00e+02, 8.00e+02],
#        [1.03e+02, 4.80e+07, 1.06e+00, ..., 3.40e+06, 3.00e+02, 8.00e+02]])

# %%
# random_state=42 for all models
from sklearn.model_selection import train_test_split
X_train_temp, X_test_temp, y_train, y_test = train_test_split(X_array, encode_y,
                                                train_size=0.75,
                                                test_size=0.25,
                                                stratify=encode_y,
                                                random_state=42)

# %%
from sklearn.impute import SimpleImputer

imp = SimpleImputer()
imp.fit(X_train_temp)
X_train = imp.transform(X_train_temp)
X_test = imp.transform(X_test_temp)
X_train
# Out:
# array([[2.62969316e+02, 9.76609876e+07, 2.81968618e+00, ...,
#         1.80612646e+07, 3.43256757e+02, 1.67957764e+03],
#        [2.62969316e+02, 9.76609876e+07, 2.81968618e+00, ...,
#         1.80612646e+07, 3.43256757e+02, 1.67957764e+03],
#        [2.62969316e+02, 9.76609876e+07, 2.81968618e+00, ...,
#         1.80612646e+07, 3.43256757e+02, 1.67957764e+03],
#        ...,
#        [6.97000000e+02, 1.75000000e+08, 2.35000000e+00, ...,
#         5.31000000e+07, 1.03000000e+03, 5.80000000e+03],
#        [2.33000000e+02, 9.76609876e+07, 2.81968618e+00, ...,
#         1.80612646e+07, 3.43256757e+02, 1.67957764e+03],
#        [2.62969316e+02, 9.76609876e+07, 2.81968618e+00, ...,
#         1.80612646e+07, 3.43256757e+02, 1.67957764e+03]])

# %%
train_df = pd.DataFrame({'conductivity': X_train[:, 0], 'hardness': X_train[:, 1],\
                       'turbidity': X_train[:, 2], 'chlorophyll': X_train[:, 3],\
                       'ammonia': X_train[:, 4], 'nitrate_ite': X_train[:, 5],\
                       'aluminum': X_train[:, 6], 'barium': X_train[:, 7],\
                       'calcium': X_train[:, 8], 'carbon': X_train[:, 9],\
                       'chloride': X_train[:, 10], 'chromium': X_train[:, 11],\
                       'copper': X_train[:, 12], 'magnesium': X_train[:, 13],\
                       'manganese': X_train[:, 14], 'mercury': X_train[:, 15],\
                       'molybdenum': X_train[:, 16], 'phosphorus': X_train[:, 17],\
                       'potassium': X_train[:, 18], 'silicon': X_train[:, 19],\
                       'sodium': X_train[:, 20], 'strontium': X_train[:, 21],\
                       'sulphate': X_train[:, 22], 'vanadium': X_train[:, 23],\
                       'zinc': X_train[:, 24]})


test_df = pd.DataFrame({'conductivity': X_test[:, 0], 'hardness': X_test[:, 1],\
                       'turbidity': X_test[:, 2], 'chlorophyll': X_test[:, 3],\
                       'ammonia': X_test[:, 4], 'nitrate_ite': X_test[:, 5],\
                       'aluminum': X_test[:, 6], 'barium': X_test[:, 7],\
                       'calcium': X_test[:, 8], 'carbon': X_test[:, 9],\
                       'chloride': X_test[:, 10], 'chromium': X_test[:, 11],\
                       'copper': X_test[:, 12], 'magnesium': X_test[:, 13],\
                       'manganese': X_test[:, 14], 'mercury': X_test[:, 15],\
                       'molybdenum': X_test[:, 16], 'phosphorus': X_test[:, 17],\
                       'potassium': X_test[:, 18], 'silicon': X_test[:, 19],\
                       'sodium': X_test[:, 20], 'strontium': X_test[:, 21],\
                       'sulphate': X_test[:, 22], 'vanadium': X_test[:, 23],\
                       'zinc': X_test[:, 24]})

# %%
train_df.head()
# Out:
#    conductivity      hardness  turbidity  chlorophyll       ammonia  \
# 0    262.969316  9.766099e+07   2.819686  2759.964436  24063.427843
# 1    262.969316  9.766099e+07   2.819686  2700.000000  28000.000000
# 2    262.969316  9.766099e+07   2.819686   400.000000  40000.000000
# 3    262.969316  9.766099e+07   2.819686   300.000000  22000.000000
# 4    292.000000  9.766099e+07   2.819686   300.000000   2000.000000
#
#      nitrate_ite      aluminum        barium       calcium        carbon  \
# 0  509731.239396  24015.412371  16681.494801  2.740428e+07  2.241818e+07
# 1   93000.000000  24015.412371  16681.494801  2.740428e+07  3.180000e+07
# 2  340000.000000  24015.412371  16681.494801  2.740428e+07  2.510000e+07
# 3  400000.000000  24015.412371  16681.494801  2.740428e+07  2.070000e+07
# 4  360000.000000  24015.412371  16681.494801  2.740428e+07  2.241818e+07
#
#        chloride    chromium       copper     magnesium    manganese  \
# 0  1.570210e+07  490.602837  1582.730721  7.176951e+06  5781.001341
# 1  1.330000e+07  490.602837  1582.730721  7.176951e+06  5781.001341
# 2  2.340000e+07  490.602837  1582.730721  7.176951e+06  5781.001341
# 3  8.200000e+06  490.602837  1582.730721  7.176951e+06  5781.001341
# 4  1.640000e+07  490.602837  1582.730721  7.176951e+06  5781.001341
#
#      mercury  molybdenum  phosphorus     potassium       silicon  \
# 0  19.957377  754.934823     75200.0  1.223461e+06  5.624687e+05
# 1  19.957377  754.934823     16500.0  1.223461e+06  1.100000e+06
# 2  19.957377  754.934823      7600.0  1.223461e+06  1.600000e+05
# 3  19.957377  754.934823      5000.0  1.223461e+06  6.200000e+05
# 4  19.957377  754.934823      9500.0  1.223461e+06  3.800000e+05
#
#          sodium      strontium      sulphate    vanadium        zinc
# 0  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 1  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 2  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 3  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 4  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764

# %%
train_df.insert(0, "lake", y_train.tolist())
train_df.head()
# Out:
#    lake  conductivity      hardness  turbidity  chlorophyll       ammonia  \
# 0     0    262.969316  9.766099e+07   2.819686  2759.964436  24063.427843
# 1     2    262.969316  9.766099e+07   2.819686  2700.000000  28000.000000
# 2     2    262.969316  9.766099e+07   2.819686   400.000000  40000.000000
# 3     1    262.969316  9.766099e+07   2.819686   300.000000  22000.000000
# 4     0    292.000000  9.766099e+07   2.819686   300.000000   2000.000000
#
#      nitrate_ite      aluminum        barium       calcium        carbon  \
# 0  509731.239396  24015.412371  16681.494801  2.740428e+07  2.241818e+07
# 1   93000.000000  24015.412371  16681.494801  2.740428e+07  3.180000e+07
# 2  340000.000000  24015.412371  16681.494801  2.740428e+07  2.510000e+07
# 3  400000.000000  24015.412371  16681.494801  2.740428e+07  2.070000e+07
# 4  360000.000000  24015.412371  16681.494801  2.740428e+07  2.241818e+07
#
#        chloride    chromium       copper     magnesium    manganese  \
# 0  1.570210e+07  490.602837  1582.730721  7.176951e+06  5781.001341
# 1  1.330000e+07  490.602837  1582.730721  7.176951e+06  5781.001341
# 2  2.340000e+07  490.602837  1582.730721  7.176951e+06  5781.001341
# 3  8.200000e+06  490.602837  1582.730721  7.176951e+06  5781.001341
# 4  1.640000e+07  490.602837  1582.730721  7.176951e+06  5781.001341
#
#      mercury  molybdenum  phosphorus     potassium       silicon  \
# 0  19.957377  754.934823     75200.0  1.223461e+06  5.624687e+05
# 1  19.957377  754.934823     16500.0  1.223461e+06  1.100000e+06
# 2  19.957377  754.934823      7600.0  1.223461e+06  1.600000e+05
# 3  19.957377  754.934823      5000.0  1.223461e+06  6.200000e+05
# 4  19.957377  754.934823      9500.0  1.223461e+06  3.800000e+05
#
#          sodium      strontium      sulphate    vanadium        zinc
# 0  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 1  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 2  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 3  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 4  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764

# %%
test_df.insert(0, "lake", y_test.tolist())
test_df.head()
# Out:
#    lake  conductivity      hardness  turbidity  chlorophyll       ammonia  \
# 0     1    248.000000  9.766099e+07   2.819686  1600.000000  18000.000000
# 1     0    262.969316  9.766099e+07   2.819686  4500.000000  26000.000000
# 2     3    262.969316  9.766099e+07   2.819686  2759.964436  24063.427843
# 3     0    297.000000  9.766099e+07   2.819686  6065.000000   2000.000000
# 4     0    262.969316  9.766099e+07   2.819686  2759.964436  16000.000000
#
#     nitrate_ite      aluminum        barium       calcium        carbon  \
# 0  1.313000e+06  24015.412371  16681.494801  2.740428e+07  2.350000e+07
# 1  9.120000e+05  24015.412371  16681.494801  2.740428e+07  2.320000e+07
# 2  5.097312e+05    100.000000  16681.494801  2.740428e+07  2.241818e+07
# 3  5.200000e+05  24015.412371  16681.494801  2.740428e+07  2.241818e+07
# 4  2.450000e+05  24015.412371  16681.494801  2.740428e+07  2.241818e+07
#
#        chloride    chromium       copper     magnesium    manganese  \
# 0  8.000000e+06  490.602837  1582.730721  7.176951e+06  5781.001341
# 1  1.170000e+07  490.602837  1582.730721  7.176951e+06  5781.001341
# 2  1.570210e+07  490.602837   100.000000  7.176951e+06  5781.001341
# 3  1.690000e+07  490.602837  1582.730721  7.176951e+06  5781.001341
# 4  1.570210e+07  490.602837  1582.730721  7.176951e+06  5781.001341
#
#      mercury  molybdenum    phosphorus     potassium        silicon  \
# 0  19.957377  754.934823  21500.000000  1.223461e+06  140000.000000
# 1  19.957377  754.934823  66900.000000  1.223461e+06  860000.000000
# 2  19.957377  754.934823  24102.070796  1.223461e+06  562468.666828
# 3  19.957377  754.934823  31000.000000  1.223461e+06  240000.000000
# 4  19.957377  754.934823  14000.000000  1.223461e+06  562468.666828
#
#          sodium      strontium      sulphate    vanadium        zinc
# 0  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 1  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 2  8.604703e+06  118046.752622  1.806126e+07  343.256757  1600.00000
# 3  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764
# 4  8.604703e+06  118046.752622  1.806126e+07  343.256757  1679.57764

# %%
from sqlalchemy import create_engine
from config.postgres import username, password


rds_connection_string = f"postgresql://{username}:{password}@awsgreatlakes.cdb9inonioij.us-east-2.rds.amazonaws.com:5432/awsgreatlakes"

engine = create_engine(rds_connection_string)

# %%
# get table names
engine.table_names()
# Out:
# ['lake_means',
#  'master_data',
#  'metadata',
#  'data',
#  'encoded_lakes',
#  'train_lakes',
#  'test_lakes']

# %%
# table headers are set up correctly
pd.read_sql_query('select * from test_lakes', con=engine)
# Out:
# Empty DataFrame
# Columns: [lake, conductivity, hardness, turbidity, chlorophyll, ammonia, nitrate_ite, aluminum, barium, calcium, carbon, chloride, chromium, copper, magnesium, manganese, mercury, molybdenum, phosphorus, potassium, silicon, sodium, strontium, sulphate, vanadium, zinc]
# Index: []

# %%
# read the pandas dataframe to the postgreSQL database
test_df.to_sql(name='test_lakes', con=engine, if_exists='append', index=False)

# %%
# table headers are set up correctly
pd.read_sql_query('select * from train_lakes', con=engine)
# Out:
# Empty DataFrame
# Columns: [lake, conductivity, hardness, turbidity, chlorophyll, ammonia, nitrate_ite, aluminum, barium, calcium, carbon, chloride, chromium, copper, magnesium, manganese, mercury, molybdenum, phosphorus, potassium, silicon, sodium, strontium, sulphate, vanadium, zinc]
# Index: []

# %%
# read the pandas dataframe to the postgreSQL database
train_df.to_sql(name='train_lakes', con=engine, if_exists='append', index=False)
